# %%
print('hello')
# Out:
# hello

# %%
import sys
print(sys.executable)
# Out:
# /Users/ericjoubert/Projects/ai-week-digest/.venv/bin/python

# %%
from v2_weekly_digest import build_graph
app = build_graph()

# %%
from IPython.display import Image, display

display(Image(app.get_graph().draw_mermaid_png()))

# %%
print(app.get_graph().draw_mermaid())
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	free_slots(free_slots)
# 	weather(weather)
# 	facts(facts)
# 	recommendations(recommendations)
# 	trello_publish(trello_publish)
# 	email(email)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> free_slots;
# 	facts --> recommendations;
# 	free_slots --> weather;
# 	recommendations --> trello_publish;
# 	trello_publish --> email;
# 	weather --> facts;
# 	email --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
app = build_graph()
mermaid = app.get_graph().draw_mermaid()
print(mermaid)
# Out:
# ---
# config:
#   flowchart:
#     curve: linear
# ---
# graph TD;
# 	__start__([<p>__start__</p>]):::first
# 	free_slots(free_slots)
# 	weather(weather)
# 	facts(facts)
# 	recommendations(recommendations)
# 	trello_publish(trello_publish)
# 	email(email)
# 	__end__([<p>__end__</p>]):::last
# 	__start__ --> free_slots;
# 	facts --> recommendations;
# 	free_slots --> weather;
# 	recommendations --> trello_publish;
# 	trello_publish --> email;
# 	weather --> facts;
# 	email --> __end__;
# 	classDef default fill:#f2f0ff,line-height:1.2
# 	classDef first fill-opacity:0
# 	classDef last fill:#bfb6fc

# %%
from IPython.display import Markdown, display

mermaid = app.get_graph().draw_mermaid()

styled = f"""
```mermaid
# %%{{init: {{
  "theme": "base",
  "themeVariables": {{
    "primaryColor": "#E8F0FE",
    "primaryTextColor": "#111111",
    "primaryBorderColor": "#4A90E2",
    "lineColor": "#7B8794",
    "secondaryColor": "#F3F4F6",
    "tertiaryColor": "#FFF7ED",
    "fontFamily": "Inter, Arial, sans-serif",
    "fontSize": "16px"
  }}
}}%%
{mermaid}"""

# %%
pretty_mermaid = """
flowchart TD
    subgraph A[Data retrieval]
        cal[Google Calendar]
        weather[Open-Meteo Weather]
        tlg[Lausanne Guide]
    end

    subgraph B[Planning logic]
        slots[Free slot computation]
        facts[Facts summary]
        recs[Recommendation agent]
    end

    subgraph C[Actions]
        trello[Trello via Zapier MCP]
        email[Weekly email]
    end

    cal --> slots
    weather --> recs
    tlg --> recs
    slots --> recs
    cal --> facts
    facts --> email
    recs --> trello
    recs --> email
"""
from IPython.display import Markdown, display

display(Markdown(f"```mermaid\n{pretty_mermaid}\n```"))
# Out:
# ```mermaid
#
# flowchart TD
#     subgraph A[Data retrieval]
#         cal[Google Calendar]
#         weather[Open-Meteo Weather]
#         tlg[Lausanne Guide]
#     end
#
#     subgraph B[Planning logic]
#         slots[Free slot computation]
#         facts[Facts summary]
#         recs[Recommendation agent]
#     end
#
#     subgraph C[Actions]
#         trello[Trello via Zapier MCP]
#         email[Weekly email]
#     end
#
#     cal --> slots
#     weather --> recs
#     tlg --> recs
#     slots --> recs
#     cal --> facts
#     facts --> email
#     recs --> trello
#     recs --> email
#
# ```
